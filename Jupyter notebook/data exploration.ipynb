# %%
import pandas as pd
import mysql.connector
import plotly.express as px

# %%
connection = mysql.connector.connect(
    host='localhost',
    user='root',
    password='19961999',
    database='nas'
)

# %%
print(connection.is_connected())
# Out:
# True

# %%
cursor = connection.cursor(buffered=True)

# %%
select_query = "SELECT * FROM orders;"

cursor.execute(select_query)

# %%
df_orders = pd.read_sql(select_query, connection)

# %%
print(df_orders.head(20))
# Out:
#                             order_id                       customer_id  \
# 0   e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1   53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2   47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3   949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4   ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# 5   a4591c265e18cb1dcee52889e2d8acc3  503740e9ca751ccdda7ba28e9ab8f608
# 6   136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 7   6514b8ad8028c9f2cc2374ded245783f  9bdf08b4b3b52b5526ff42d37d47f222
# 8   76c6e866289321a7c93b82b54852dc33  f54a9f0e6b351c431402b8461ea51999
# 9   e69bfb5eb88e0ed6a785585b27e16dbf  31ad1d1b63eb9962463f764d4e6e0c9d
# 10  e6ce16cb79ec1d90b1da9085a6118aeb  494dded5b201313c64ed7f100595b95c
# 11  34513ce0c4fab462a55830c0989c7edb  7711cf624183d843aafe81855097bc37
# ...

# %%
select_query_product_sales = """SELECT order_items.product_id, COUNT(order_items.product_id) AS Product_Sales, 
categories.product_category_name_english AS Category, products.product_photos_qty AS Images_Number
from products
LEFT JOIN order_items ON order_items.product_id=products.product_id
LEFT JOIN categories ON categories.product_category_name=products.product_category_name
GROUP BY order_items.product_id
ORDER BY Product_sales DESC;"""

cursor.execute(select_query_product)

# %%
df_product_sales = pd.read_sql(select_query_product_sales, connection)
# Out:
# C:\Users\nasrn\anaconda3\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
print(df_product_sales.head(20))
# Out:
#                           product_id  Product_Sales               Category  \
# 0   aca2eb7d00ea1a7b8ebd4e68314663af            527        furniture_decor
# 1   99a4788cb24856965c36a24e339b6058            488         bed_bath_table
# 2   422879e10f46682990de24d770e7f83d            484           garden_tools
# 3   389d119b48cf3043d311335e499d9c6b            392           garden_tools
# 4   368c6c730842d78016ad823897a372db            388           garden_tools
# 5   53759a2ecddad2bb87a079a1f1519f73            373           garden_tools
# 6   d1c427060a0f73f6b889a5c7c61f2ac4            343  computers_accessories
# 7   53b36df67ebb7c41585e8d54d6772e08            323          watches_gifts
# 8   154e7e31ebfa092203795c972e5804a6            281          health_beauty
# 9   3dd2a17168ec895c781a9191c1e95ad7            274  computers_accessories
# 10  2b4609f8948be18874494203496bc318            260          health_beauty
# ...

# %%
select_query_average_product_sales="""SELECT COUNT(DISTINCT order_items.product_id) AS Number_of_Products, 
COUNT(order_items.product_id) AS Product_Sales,COUNT(order_items.product_id)/COUNT(DISTINCT order_items.product_id) AS Average_Sales_Per_Product, products.product_photos_qty AS Images_Number
FROM products
LEFT JOIN order_items ON order_items.product_id=products.product_id
GROUP BY products.product_photos_qty
ORDER BY products.product_photos_qty DESC;"""

cursor.execute(select_query_average_product_sales)

# %%
df_average_product_sales = pd.read_sql(select_query_average_product_sales, connection)
# Out:
# C:\Users\nasrn\anaconda3\lib\site-packages\pandas\io\sql.py:762: UserWarning:
#
# pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy

# %%
df_average_product_sales['Images_Number'].fillna(0, inplace=True)

print(df_average_product_sales.head(20))
# Out:
#     Number_of_Products  Product_Sales  Average_Sales_Per_Product  \
# 0                    1              1                     1.0000
# 1                    1              2                     2.0000
# 2                    2              4                     2.0000
# 3                    7             11                     1.5714
# 4                    8             12                     1.5000
# 5                    5              6                     1.2000
# 6                    9             30                     3.3333
# 7                   35             53                     1.5143
# 8                   46             71                     1.5435
# 9                   95            342                     3.6000
# 10                 105            313                     2.9810
# 11                 192            727                     3.7865
# 12                 343           1501                     4.3761
# ...

# %%
bar_plot_img_qty=px.bar(df_average_product_sales,x = 'Images_Number',y = 'Average_Sales_Per_Product')

bar_plot_img_qty.show() #excessive use of images might reduce sales of products same with the lack of any images
# Out:
# <div>                            <div id="d6548e58-3365-460a-9123-c27b2d6d45bd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d6548e58-3365-460a-9123-c27b2d6d45bd")) {                    Plotly.newPlot(                        "d6548e58-3365-460a-9123-c27b2d6d45bd",                        [{"alignmentgroup":"True","hovertemplate":"Images_Number=%{x}<br>Average_Sales_Per_Product=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[20.0,19.0,18.0,17.0,15.0,14.0,13.0,12.0,11.0,10.0,9.0,8.0,7.0,6.0,5.0,4.0,3.0,2.0,1.0,0.0],"xaxis":"x","y":[1.0,2.0,2.0,1.5714,1.5,1.2,3.3333,1.5143,1.5435,3.6,2.981,3.7865,4.3761,3.9112,3.6173,3.
# ...

# %%
select_query_category_sales = """SELECT COUNT(order_items.product_id) AS Category_Sales, categories.product_category_name_english AS Category
FROM products
LEFT JOIN order_items on order_items.product_id=products.product_id
LEFT JOIN categories ON categories.product_category_name=products.product_category_name
GROUP BY products.product_category_name
ORDER BY Category_Sales DESC;"""
cursor.execute(select_query_category_sales)

# %%
df_category_sales = pd.read_sql(select_query_category_sales, connection)
# Out:
# C:\Users\nasrn\anaconda3\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
df_category_sales = df_category_sales.dropna()

# %%
df_category_sales['Category'] = df_category_sales['Category'].str.replace('_', ' ')
df_category_sales['Category'] = df_category_sales['Category'].str.title()

# %%
print(df_category_sales.head(20))
# Out:
#     Category_Sales                  Category
# 0            11115            Bed Bath Table
# 1             9670             Health Beauty
# 2             8641            Sports Leisure
# 3             8334           Furniture Decor
# 4             7827     Computers Accessories
# 5             6964                Housewares
# 6             5991             Watches Gifts
# 7             4545                 Telephony
# 8             4347              Garden Tools
# 9             4235                      Auto
# 10            4117                      Toys
# 11            3796                Cool Stuff
# 12            3419                 Perfumery
# 13            3065                      Baby
# 14            2767               Electronics
# 15            2517                Stationery
# 16            2031  Fashion Bags Accessories
# 17            1947                  Pet Shop
# 18            1691          Office Furniture
# 20            1137            Consoles Games

# %%
print(df_category_sales.tail(20))
# Out:
#     Category_Sales                               Category
# 52             109                      Furniture Bedroom
# 53             103                Costruction Tools Tools
# 54              83                 Tablets Printing Image
# 55              76  Small Appliances Home Oven And Coffee
# 56              72                             Cine Photo
# 57              64                           Dvds Blu Ray
# 58              60                         Books Imported
# 59              48                 Fashio Female Clothing
# 60              43                         Party Supplies
# 61              39                    Diapers And Hygiene
# 62              38                                  Music
# 63              38      Furniture Mattress And Upholstery
# 64              33                                Flowers
# 65              30                         Home Comfort 2
# 66              30                          Fashion Sport
# ...

# %%
fig_category_performance = px.bar(df_category_sales,x = 'Category',y = 'Category_Sales')

fig_category_performance.show() #the most popular category is bed bath & table
# Out:
# <div>                            <div id="543add17-7317-443d-9777-ef02653504bb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("543add17-7317-443d-9777-ef02653504bb")) {                    Plotly.newPlot(                        "543add17-7317-443d-9777-ef02653504bb",                        [{"alignmentgroup":"True","hovertemplate":"Category=%{x}<br>Category_Sales=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Bed Bath Table","Health Beauty","Sports Leisure","Furniture Decor","Computers Accessories","Housewares","Watches Gifts","Telephony","Garden Tools","Auto","Toys","Cool Stuff","Perfumery","Baby","Electronics","Sta
# ...

# %%
select_query_orders_value = """SELECT order_items.order_id,SUM(order_items.price) AS order_value
FROM order_items
GROUP BY order_items.order_id"""

cursor.execute(select_query_orders_value)

# %%
df_orders_value = pd.read_sql(select_query_orders_value, connection)
# Out:
# C:\Users\nasrn\anaconda3\lib\site-packages\pandas\io\sql.py:762: UserWarning:
#
# pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy

# %%
print(df_orders_value.head(20))
# Out:
#                             order_id  order_value
# 0   00010242fe8c5a6d1ba2dd792cb16214        58.90
# 1   00018f77f2f0320c557190d7a144bdd3       239.90
# 2   000229ec398224ef6ca0657da4fc703e       199.00
# 3   00024acbcdf0a6daa1e931b038114c75        12.99
# 4   00042b26cf59d7ce69dfabb4e55b4fd9       199.90
# 5   00048cc3ae777c65dbb7d2a0634bc1ea        21.90
# 6   00054e8431b9d7675808bcb819fb4a32        19.90
# 7   000576fe39319847cbb9d288c5617fa6       810.00
# 8   0005a1a1728c9d785b8e2b08b904576c       145.95
# 9   0005f50442cb953dcd1d21e1fb923495        53.99
# 10  00061f2a7bc09da83e415a52dc8a4af1        59.99
# 11  00063b381e2406b52ad429470734ebd5        45.00
# 12  0006ec9db01a64e59a68b2c340bf65a7        74.00
# 13  0008288aa423d2a3f00fcb17cd7d8719        99.80
# 14  0009792311464db532ff765bf7b182ae        99.90
# 15  0009c9a17f916a706d71784483a5d643       639.00
# 16  000aed2e25dbad2f9ddb70584c5a2ded       144.00
# 17  000c3e6612759851cc3cbb4b83257986        99.00
# ...

# %%
histogram_orders=px.histogram(df_orders_value,x = 'order_value')

histogram_orders.update_layout(
    xaxis_title='orders value',
    yaxis_title='number of orders'
)

histogram_orders.show()
# Out:
# <div>                            <div id="66acb218-a6ac-43e8-b42d-4de4605f1cbc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("66acb218-a6ac-43e8-b42d-4de4605f1cbc")) {                    Plotly.newPlot(                        "66acb218-a6ac-43e8-b42d-4de4605f1cbc",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"order_value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[58.9,239.9,199.0,12.99,199.9,21.9,19.9,810.0,145.95,53.99,59.99,45.0,74.0,99.8,99.9,639.0,144.0,99.0,25.0,47.9,21.99,119.99,49.0,48.9,219.9,289.0,109.9,27.9,119.9,397.0,59.9,63.989999999999995,16.5,21.9,39.0,49.75,809.1,99.99
# ...

# %%
order_value_percentiles = df_orders_value['order_value'].quantile(.9)

print(order_value_percentiles) #90% of orders don't exceed 270$
# Out:
# 269.9

# %%
select_query_payment_method="""SELECT payment_type, COUNT(payment_type) AS Number_of_Payments
FROM order_payments
GROUP BY payment_type"""
cursor.execute(select_query_payment_method)

# %%
df_payment_method = pd.read_sql(select_query_payment_method, connection)
# Out:
# C:\Users\nasrn\anaconda3\lib\site-packages\pandas\io\sql.py:762: UserWarning:
#
# pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy

# %%
df_payment_method['payment_type'] = df_payment_method['payment_type'].str.replace('_', ' ')
df_payment_method['payment_type'] = df_payment_method['payment_type'].str.title()

# %%
print(df_payment_method)
# Out:
#   payment_type  Number_of_Payments
# 0  Credit Card               76795
# 1       Boleto               19784
# 2      Voucher                5775
# 3   Debit Card                1529
# 4  Not Defined                   3

# %%
bar_chart_payment_method = px.bar(df_payment_method,x = 'payment_type', y='Number_of_Payments')
bar_chart_payment_method.update_layout(
    xaxis_title='Payment Method',
    yaxis_title='Number of Transactions')
bar_chart_payment_method.show()
# Out:
# <div>                            <div id="3d2e6fa8-8e30-4e78-8e92-2040d3b7dcbd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3d2e6fa8-8e30-4e78-8e92-2040d3b7dcbd")) {                    Plotly.newPlot(                        "3d2e6fa8-8e30-4e78-8e92-2040d3b7dcbd",                        [{"alignmentgroup":"True","hovertemplate":"payment_type=%{x}<br>Number_of_Payments=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Credit Card","Boleto","Voucher","Debit Card","Not Defined"],"xaxis":"x","y":[76795,19784,5775,1529,3],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type"
# ...

# %%
select_query_delivery_time = """SELECT order_id AS Orders, order_purchase_timestamp AS order_placement, order_delivered_customer_date AS order_delivery
FROM orders"""
cursor.execute(select_query_delivery_time)

# %%
df_delivery_time = pd.read_sql(select_query_delivery_time, connection)

df_delivery_time_types= df_delivery_time.dtypes
# Out:
# C:\Users\nasrn\anaconda3\lib\site-packages\pandas\io\sql.py:762: UserWarning:
#
# pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy

# %%
print(df_delivery_time_types)
# Out:
# Orders             object
# order_placement    object
# order_delivery     object
# dtype: object

# %%
df_delivery_time['order_placement'] = pd.to_datetime(df_delivery_time['order_placement'])
df_delivery_time['order_delivery'] = pd.to_datetime(df_delivery_time['order_delivery'])

df_delivery_time['order_placement'] = df_delivery_time['order_placement'].dt.date
df_delivery_time['order_delivery'] = df_delivery_time['order_delivery'].dt.date

# %%
df_delivery_time['delivery_duartion'] = df_delivery_time['order_delivery']-df_delivery_time['order_placement']

# %%
print(df_delivery_time)
# Out:
#                                  Orders order_placement order_delivery  \
# 0      e481f51cbdc54678b7cc49136f2d6af7      2017-10-02     2017-10-10
# 1      53cdb2fc8bc7dce0b6741e2150273451      2018-07-24     2018-08-07
# 2      47770eb9100c2d0c44946d9cf07ec65d      2018-08-08     2018-08-17
# 3      949d5b44dbf5de918fe9c16f97b45f8a      2017-11-18     2017-12-02
# 4      ad21c59c0840e6cb83a9ceb5573f8159      2018-02-13     2018-02-16
# ...                                 ...             ...            ...
# 99436  9c5dedf39a927c1b2549525ed64a053c      2017-03-09     2017-03-17
# 99437  63943bddc261676b46f01ca7ac2f7bd8      2018-02-06     2018-02-28
# 99438  83c1379a015df1e13d02aae0204711ab      2017-08-27     2017-09-21
# 99439  11c177c8e97725db2631073c19f07b62      2018-01-08     2018-01-25
# 99440  66dea50a8b16d9b4dee7af250b4be1a5      2018-03-08     2018-03-16
#
#       delivery_duartion
# 0                8 days
# 1               14 days
# 2                9 days
# ...

# %%
average_delivery_time = df_delivery_time['delivery_duartion'].mean()

print(average_delivery_time) #the average delivery time is around 12 days
# Out:
# 12 days 11:56:09.841204030

# %%
df_orders_by_date = df_delivery_time.groupby('order_placement')['Orders'].count().reset_index()

# %%
print(df_orders_by_date.head(30))
# Out:
#    order_placement  Orders
# 0       2016-09-04       1
# 1       2016-09-05       1
# 2       2016-09-13       1
# 3       2016-09-15       1
# 4       2016-10-02       1
# 5       2016-10-03       8
# 6       2016-10-04      63
# 7       2016-10-05      47
# 8       2016-10-06      51
# 9       2016-10-07      46
# 10      2016-10-08      42
# 11      2016-10-09      26
# 12      2016-10-10      39
# 13      2016-10-22       1
# 14      2016-12-23       1
# 15      2017-01-05      32
# 16      2017-01-06       4
# 17      2017-01-07       4
# 18      2017-01-08       6
# 19      2017-01-09       5
# 20      2017-01-10       6
# 21      2017-01-11      12
# 22      2017-01-12      13
# 23      2017-01-13      12
# 24      2017-01-14      18
# 25      2017-01-15      14
# 26      2017-01-16      19
# 27      2017-01-17      32
# 28      2017-01-18      33
# 29      2017-01-19      29

# %%
orders_line_plot = px.line(df_orders_by_date,x = 'order_placement', y = 'Orders')
orders_line_plot.show() #the orders spike in 24 november 2017 can be attributed to the occurrence of black friday
# Out:
# <div>                            <div id="60750e3d-1eb6-48b0-8781-e46e281ad62d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("60750e3d-1eb6-48b0-8781-e46e281ad62d")) {                    Plotly.newPlot(                        "60750e3d-1eb6-48b0-8781-e46e281ad62d",                        [{"hovertemplate":"order_placement=%{x}<br>Orders=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2016-09-04","2016-09-05","2016-09-13","2016-09-15","2016-10-02","2016-10-03","2016-10-04","2016-10-05","2016-10-06","2016-10-07","2016-10-08","2016-10-09","2016-10-10","2016-10-22","2016-12-23","2017-01-05","2017-01-06","2017-01-07","2017-01
# ...
